# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, roc_curve, auc, precision_recall_curve, average_precision_score
from sklearn.preprocessing import label_binarize
import matplotlib.pyplot as plt


def print_score(y_pred, y_real, y_score, label_encoder, model_name):
    data = []
    
    data.append(["Accuracy", accuracy_score(y_real, y_pred)])
    data.append(["Precision (macro)", precision_score(y_real, y_pred, average='macro')])
    data.append(["Recall (macro)", recall_score(y_real, y_pred, average='macro')])
    data.append(["F1-score (macro)", f1_score(y_real, y_pred, average='macro')])
    data.append(["AUC-ROC (macro)", roc_auc_score(y_real, y_score, multi_class='ovr', average='macro')])
    
    for i in range(len(label_encoder.classes_)):
        class_name = label_encoder.inverse_transform([i])[0]
        data.append([f"Precision ({class_name})", precision_score(y_real, y_pred, labels=[i], average='weighted')])
        data.append([f"Recall ({class_name})", recall_score(y_real, y_pred, labels=[i], average='weighted')])
        data.append([f"F1-score ({class_name})", f1_score(y_real, y_pred, labels=[i], average='weighted')])
    
    score_df = pd.DataFrame(data, columns=["Metric", "Value"])
    display(score_df)

    # Save the score DataFrame to a CSV file
    score_df.to_csv(f"{model_name}_metrics.csv", index=False)


def plot_roc_curve(y_true, y_score, label_encoder, model_name):
    n_classes = len(label_encoder.classes_)

    if n_classes == 2:
        fpr, tpr, _ = roc_curve(y_true, y_score[:, 1])
        roc_auc = auc(fpr, tpr)

        plt.figure(figsize=(10, 6)) 
        lw = 2
        plt.plot(fpr, tpr, color='darkorange', lw=lw, label='ROC curve (area = %0.2f)' % roc_auc)
        plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
        plt.xlim([0.0, 1.0])
        plt.ylim([0.0, 1.05])
        plt.xlabel('False Positive Rate')
        plt.ylabel('True Positive Rate')
        plt.title('Receiver Operating Characteristic (ROC) curve')
        plt.legend(loc="best", bbox_to_anchor=(1.05, 1), borderaxespad=0.)
        plt.show()
    else:
        fpr = dict()
        tpr = dict()
        roc_auc = dict()
        for i in range(n_classes):
            fpr[i], tpr[i], _ = roc_curve(y_true, y_score[:, i], pos_label=i)
            roc_auc[i] = auc(fpr[i], tpr[i])

        plt.figure(figsize=(10, 6))
        for i in range(n_classes):
            class_name = label_encoder.inverse_transform([i])[0]
            plt.plot(fpr[i], tpr[i], lw=2, label='ROC curve of class {0} (area = {1:0.2f})'.format(class_name, roc_auc[i]))

        plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
        plt.xlim([0.0, 1.0])
        plt.ylim([0.0, 1.05])
        plt.xlabel('False Positive Rate')
        plt.ylabel('True Positive Rate')
        plt.title('Receiver Operating Characteristic (ROC) curve for multi-class')
        plt.legend(loc="best", bbox_to_anchor=(1.05, 1), borderaxespad=0.)
        plt.show()
        fig = plt.gcf()  # Get the current figure
        # Save the figure to an image file
        fig.savefig(f"{model_name}_roc_curve.png", bbox_inches='tight')


from sklearn.metrics import PrecisionRecallDisplay

def plot_precision_recall_curve(y_true, y_score, label_encoder, model_name):
    n_classes = len(label_encoder.classes_)

    if n_classes == 2:
        precision, recall, _ = precision_recall_curve(y_true, y_score[:, 1])
        average_precision = average_precision_score(y_true, y_score[:, 1])

        plt.figure(figsize=(10, 6))  # Change the figure size here
        plt.step(recall, precision, where='post')
        plt.xlabel('Recall')
        plt.ylabel('Precision')
        plt.ylim([0.0, 1.05])
        plt.xlim([0.0, 1.0])
        plt.title('2-class Precision-Recall curve: AP={0:0.2f}'.format(average_precision))
        plt.show()
    else:
        y_true_binarized = label_binarize(y_true, classes=list(range(n_classes)))
        precision = dict()
        recall = dict()
        average_precision = dict()

        for i in range(n_classes):
            precision[i], recall[i], _ = precision_recall_curve(y_true_binarized[:, i], y_score[:, i])
            average_precision[i] = average_precision_score(y_true_binarized[:, i], y_score[:, i], average=None)

        # Plot Precision-Recall curve for each class
        plt.figure(figsize=(10, 6))  # Change the figure size here
        for i in range(n_classes):
            disp = PrecisionRecallDisplay(precision=precision[i], recall=recall[i])
            class_name = label_encoder.inverse_transform([i])[0]
            disp.plot(ax=plt.gca(), label='Precision-recall curve of class {0} (AP = {1:0.2f})'.format(class_name, average_precision[i]))

        plt.xlabel('Recall')
        plt.ylabel('Precision')
        plt.ylim([0.0, 1.05])
        plt.xlim([0.0, 1.0])
        plt.title('Precision-Recall curve for multi-class')
        plt.legend(loc="best", bbox_to_anchor=(1.05, 1), borderaxespad=0.)
        plt.show()
        fig = plt.gcf()  # Get the current figure
        # Save the figure to an image file
        fig.savefig(f"{model_name}_roc_curve.png", bbox_inches='tight')

def plot_class_accuracy(y_true, y_pred, label_encoder):
    n_classes = len(label_encoder.classes_)
    class_counts = np.zeros(n_classes)
    class_corrects = np.zeros(n_classes)

    for t, p in zip(y_true, y_pred):
        class_counts[t] += 1
        if t == p:
            class_corrects[t] += 1

    class_accuracies = class_corrects / class_counts
    class_names = label_encoder.inverse_transform(range(n_classes))

    plt.figure(figsize=(10, 6))
    plt.bar(class_names, class_accuracies)
    plt.xlabel('Class')
    plt.ylabel('Accuracy')
    plt.title('Accuracy per Class')
    plt.xticks(rotation=45)
    plt.ylim([0.0, 1.05])
    plt.show()
    fig = plt.gcf()  # Get the current figure
    # Save the figure to an image file
    fig.savefig(f"{model_name}_class_accuracy.png", bbox_inches='tight')


# Load the dataset
file_path = '/content/drive/MyDrive/UNSW_NB15_training-set.csv'
df = pd.read_csv(file_path)

# %%
# from google.colab import drive
# drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv1D, MaxPooling1D, Flatten, Dropout
from tensorflow.keras.utils import to_categorical

model_name = 'CNN'

# Convert categorical variables to dummy variables
cat_columns = ['proto', 'service', 'state']
df = pd.get_dummies(df, columns=cat_columns)

# Split the dataset into features and target
X = df.drop(['attack_cat', 'label'], axis=1)
y = df['attack_cat']

# Encode the target variable
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# One-hot encode the target variable for use with a CNN
y_onehot = to_categorical(y_encoded)

# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y_onehot, test_size=0.3, random_state=42)

# Scale the features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Reshape the input data into 3D format for use with Conv1D (samples, timesteps, features)
X_train_scaled = X_train_scaled.reshape(X_train_scaled.shape[0], X_train_scaled.shape[1], 1)
X_test_scaled = X_test_scaled.reshape(X_test_scaled.shape[0], X_test_scaled.shape[1], 1)

# Define the CNN architecture
model = Sequential()
model.add(Conv1D(32, kernel_size=3, activation='relu', input_shape=(X_train_scaled.shape[1], 1)))
model.add(MaxPooling1D(pool_size=2))
model.add(Conv1D(64, kernel_size=3, activation='relu'))
model.add(MaxPooling1D(pool_size=2))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(label_encoder.classes_), activation='softmax'))

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train the model
model.fit(X_train_scaled, y_train, batch_size=64, epochs=100, validation_split=0.2)
# Out:
# Epoch 1/100
# 721/721 [==============================] - 24s 32ms/step - loss: 0.6368 - accuracy: 0.7952 - val_loss: 0.4425 - val_accuracy: 0.8467
# Epoch 2/100
# 721/721 [==============================] - 20s 28ms/step - loss: 0.4284 - accuracy: 0.8511 - val_loss: 0.3971 - val_accuracy: 0.8522
# Epoch 3/100
# 721/721 [==============================] - 23s 32ms/step - loss: 0.3908 - accuracy: 0.8603 - val_loss: 0.3738 - val_accuracy: 0.8580
# Epoch 4/100
# 721/721 [==============================] - 20s 28ms/step - loss: 0.3737 - accuracy: 0.8651 - val_loss: 0.3539 - val_accuracy: 0.8618
# Epoch 5/100
# 721/721 [==============================] - 22s 31ms/step - loss: 0.3573 - accuracy: 0.8699 - val_loss: 0.3516 - val_accuracy: 0.8627
# Epoch 6/100
# 721/721 [==============================] - 20s 28ms/step - loss: 0.3458 - accuracy: 0.8723 - val_loss: 0.3383 - val_accuracy: 0.8656
# Epoch 7/100
# 721/721 [==============================] - 21s 30ms/step - loss: 0.3366 - accuracy: 0.8746 - val_loss: 0.3378 - val_accuracy: 0.8711
# Epoch 8/100
# 721/721 [==============================] - 21s 29ms/step - loss: 0.3286 - accuracy: 0.8770 - val_loss: 0.3244 - val_accuracy: 0.8721
# Epoch 9/100
# 721/721 [==============================] - 21s 28ms/step - loss: 0.3240 - accuracy: 0.8791 - val_loss: 0.3247 - val_accuracy: 0.8727
# Epoch 10/100
# 721/721 [==============================] - 23s 32ms/step - loss: 0.3174 - accuracy: 0.8788 - val_loss: 0.3201 - val_accuracy: 0.8728
# Epoch 11/100
# 721/721 [==============================] - 20s 28ms/step - loss: 0.3124 - accuracy: 0.8796 - val_loss: 0.3187 - val_accuracy: 0.8757
# Epoch 12/100
# 721/721 [==============================] - 22s 30ms/step - loss: 0.3081 - accuracy: 0.8814 - val_loss: 0.3089 - val_accuracy: 0.8787
# Epoch 13/100
# 721/721 [==============================] - 20s 28ms/step - loss: 0.3044 - accuracy: 0.8827 - val_loss: 0.3077 - val_accuracy: 0.8788
# Epoch 14/100
# 721/721 [==============================] - 22s 30ms/step - loss: 0.3007 - accuracy: 0.8825 - val_loss: 0.3061 - val_accuracy: 0.8798
# Epoch 15/100
# 721/721 [==============================] - 20s 28ms/step - loss: 0.2966 - accuracy: 0.8842 - val_loss: 0.3090 - val_accuracy: 0.8784
# Epoch 16/100
# 721/721 [==============================] - 21s 30ms/step - loss: 0.2933 - accuracy: 0.8847 - val_loss: 0.3068 - val_accuracy: 0.8779
# Epoch 17/100
# 721/721 [==============================] - 21s 29ms/step - loss: 0.2912 - accuracy: 0.8871 - val_loss: 0.3035 - val_accuracy: 0.8792
# Epoch 18/100
# 721/721 [==============================] - 22s 30ms/step - loss: 0.2885 - accuracy: 0.8866 - val_loss: 0.3031 - val_accuracy: 0.8805
# Epoch 19/100
# 721/721 [==============================] - 21s 29ms/step - loss: 0.2867 - accuracy: 0.8869 - val_loss: 0.3041 - val_accuracy: 0.8786
# Epoch 20/100
# 721/721 [==============================] - 20s 28ms/step - loss: 0.2833 - accuracy: 0.8874 - val_loss: 0.2971 - val_accuracy: 0.8785
# Epoch 21/100
# 721/721 [==============================] - 22s 31ms/step - loss: 0.2827 - accuracy: 0.8878 - val_loss: 0.2975 - val_accuracy: 0.8797
# Epoch 22/100
# 721/721 [==============================] - 20s 28ms/step - loss: 0.2792 - accuracy: 0.8893 - val_loss: 0.2976 - val_accuracy: 0.8805
# Epoch 23/100
# 721/721 [==============================] - 23s 32ms/step - loss: 0.2772 - accuracy: 0.8895 - val_loss: 0.3064 - val_accuracy: 0.8795
# Epoch 24/100
# 721/721 [==============================] - 23s 31ms/step - loss: 0.2764 - accuracy: 0.8902 - val_loss: 0.2950 - val_accuracy: 0.8807
# Epoch 25/100
# 721/721 [==============================] - 21s 30ms/step - loss: 0.2758 - accuracy: 0.8900 - val_loss: 0.2994 - val_accuracy: 0.8810
# Epoch 26/100
# 721/721 [==============================] - 20s 28ms/step - loss: 0.2720 - accuracy: 0.8903 - val_loss: 0.3018 - val_accuracy: 0.8797
# Epoch 27/100
# 721/721 [==============================] - 20s 28ms/step - loss: 0.2725 - accuracy: 0.8907 - val_loss: 0.2966 - val_accuracy: 0.8800
# Epoch 28/100
# 721/721 [==============================] - 22s 30ms/step - loss: 0.2689 - accuracy: 0.8928 - val_loss: 0.2980 - val_accuracy: 0.8805
# Epoch 29/100
# 721/721 [==============================] - 20s 28ms/step - loss: 0.2700 - accuracy: 0.8910 - val_loss: 0.2998 - val_accuracy: 0.8807
# Epoch 30/100
# 721/721 [==============================] - 23s 32ms/step - loss: 0.2671 - accuracy: 0.8907 - val_loss: 0.2945 - val_accuracy: 0.8792
# Epoch 31/100
# 721/721 [==============================] - 20s 28ms/step - loss: 0.2665 - accuracy: 0.8912 - val_loss: 0.2932 - val_accuracy: 0.8822
# Epoch 32/100
# 721/721 [==============================] - 22s 30ms/step - loss: 0.2643 - accuracy: 0.8912 - val_loss: 0.2950 - val_accuracy: 0.8798
# Epoch 33/100
# 721/721 [==============================] - 20s 28ms/step - loss: 0.2659 - accuracy: 0.8912 - val_loss: 0.3065 - val_accuracy: 0.8838
# Epoch 34/100
# 721/721 [==============================] - 20s 28ms/step - loss: 0.2614 - accuracy: 0.8914 - val_loss: 0.3085 - val_accuracy: 0.8825
# Epoch 35/100
# 721/721 [==============================] - 22s 30ms/step - loss: 0.2613 - accuracy: 0.8929 - val_loss: 0.2944 - val_accuracy: 0.8854
# Epoch 36/100
# 721/721 [==============================] - 20s 28ms/step - loss: 0.2622 - accuracy: 0.8930 - val_loss: 0.2939 - val_accuracy: 0.8819
# Epoch 37/100
# 721/721 [==============================] - 22s 30ms/step - loss: 0.2585 - accuracy: 0.8924 - val_loss: 0.3058 - val_accuracy: 0.8815
# Epoch 38/100
# 721/721 [==============================] - 20s 28ms/step - loss: 0.2566 - accuracy: 0.8962 - val_loss: 0.3113 - val_accuracy: 0.8823
# Epoch 39/100
# 721/721 [==============================] - 22s 30ms/step - loss: 0.2578 - accuracy: 0.8944 - val_loss: 0.2908 - val_accuracy: 0.8824
# Epoch 40/100
# 721/721 [==============================] - 20s 28ms/step - loss: 0.2570 - accuracy: 0.8944 - val_loss: 0.2941 - val_accuracy: 0.8844
# Epoch 41/100
# 721/721 [==============================] - 21s 29ms/step - loss: 0.2547 - accuracy: 0.8950 - val_loss: 0.3016 - val_accuracy: 0.8837
# Epoch 42/100
# 721/721 [==============================] - 21s 29ms/step - loss: 0.2538 - accuracy: 0.8962 - val_loss: 0.2957 - val_accuracy: 0.8833
# Epoch 43/100
# 721/721 [==============================] - 20s 28ms/step - loss: 0.2546 - accuracy: 0.8947 - val_loss: 0.2940 - val_accuracy: 0.8826
# Epoch 44/100
# 721/721 [==============================] - 22s 30ms/step - loss: 0.2535 - accuracy: 0.8945 - val_loss: 0.3010 - val_accuracy: 0.8843
# Epoch 45/100
# 721/721 [==============================] - 20s 28ms/step - loss: 0.2533 - accuracy: 0.8954 - val_loss: 0.2887 - val_accuracy: 0.8823
# Epoch 46/100
# 721/721 [==============================] - 23s 32ms/step - loss: 0.2511 - accuracy: 0.8948 - val_loss: 0.2905 - val_accuracy: 0.8824
# Epoch 47/100
# 721/721 [==============================] - 20s 28ms/step - loss: 0.2495 - accuracy: 0.8960 - val_loss: 0.3018 - val_accuracy: 0.8840
# Epoch 48/100
# 721/721 [==============================] - 22s 30ms/step - loss: 0.2482 - accuracy: 0.8975 - val_loss: 0.2847 - val_accuracy: 0.8832
# Epoch 49/100
# 721/721 [==============================] - 20s 28ms/step - loss: 0.2503 - accuracy: 0.8953 - val_loss: 0.2951 - val_accuracy: 0.8838
# Epoch 50/100
# 721/721 [==============================] - 21s 30ms/step - loss: 0.2493 - accuracy: 0.8975 - val_loss: 0.3107 - val_accuracy: 0.8826
# Epoch 51/100
# 721/721 [==============================] - 24s 33ms/step - loss: 0.2466 - accuracy: 0.8963 - val_loss: 0.3090 - val_accuracy: 0.8836
# Epoch 52/100
# 721/721 [==============================] - 23s 31ms/step - loss: 0.2480 - accuracy: 0.8981 - val_loss: 0.2953 - val_accuracy: 0.8838
# Epoch 53/100
# 721/721 [==============================] - 20s 28ms/step - loss: 0.2468 - accuracy: 0.8977 - val_loss: 0.3022 - val_accuracy: 0.8851
# Epoch 54/100
# 721/721 [==============================] - 22s 30ms/step - loss: 0.2440 - accuracy: 0.8985 - val_loss: 0.3049 - val_accuracy: 0.8831
# Epoch 55/100
# 721/721 [==============================] - 20s 28ms/step - loss: 0.2438 - accuracy: 0.8986 - val_loss: 0.2984 - val_accuracy: 0.8827
# Epoch 56/100
# 721/721 [==============================] - 21s 30ms/step - loss: 0.2487 - accuracy: 0.8969 - val_loss: 0.3022 - val_accuracy: 0.8804
# Epoch 57/100
# 721/721 [==============================] - 21s 29ms/step - loss: 0.2420 - accuracy: 0.8984 - val_loss: 0.3117 - val_accuracy: 0.8827
# Epoch 58/100
# 721/721 [==============================] - 20s 28ms/step - loss: 0.2442 - accuracy: 0.8980 - val_loss: 0.2935 - val_accuracy: 0.8812
# Epoch 59/100
# 721/721 [==============================] - 22s 31ms/step - loss: 0.2427 - accuracy: 0.8971 - val_loss: 0.3186 - val_accuracy: 0.8824
# Epoch 60/100
# 721/721 [==============================] - 20s 28ms/step - loss: 0.2437 - accuracy: 0.8992 - val_loss: 0.3052 - val_accuracy: 0.8845
# Epoch 61/100
# 721/721 [==============================] - 23s 31ms/step - loss: 0.2422 - accuracy: 0.8984 - val_loss: 0.3071 - val_accuracy: 0.8846
# Epoch 62/100
# 721/721 [==============================] - 20s 28ms/step - loss: 0.2398 - accuracy: 0.8990 - val_loss: 0.3067 - val_accuracy: 0.8830
# Epoch 63/100
# 721/721 [==============================] - 22s 30ms/step - loss: 0.2422 - accuracy: 0.8988 - val_loss: 0.2926 - val_accuracy: 0.8848
# Epoch 64/100
# 721/721 [==============================] - 20s 28ms/step - loss: 0.2411 - accuracy: 0.8984 - val_loss: 0.2986 - val_accuracy: 0.8822
# Epoch 65/100
# 721/721 [==============================] - 21s 30ms/step - loss: 0.2387 - accuracy: 0.8989 - val_loss: 0.3265 - val_accuracy: 0.8822
# Epoch 66/100
# 721/721 [==============================] - 21s 29ms/step - loss: 0.2372 - accuracy: 0.8981 - val_loss: 0.3113 - val_accuracy: 0.8833
# Epoch 67/100
# 721/721 [==============================] - 20s 28ms/step - loss: 0.2390 - accuracy: 0.8982 - val_loss: 0.3025 - val_accuracy: 0.8847
# Epoch 68/100
# 721/721 [==============================] - 22s 30ms/step - loss: 0.2355 - accuracy: 0.8994 - val_loss: 0.3139 - val_accuracy: 0.8855
# Epoch 69/100
# 721/721 [==============================] - 20s 28ms/step - loss: 0.2374 - accuracy: 0.8998 - val_loss: 0.2966 - val_accuracy: 0.8837
# Epoch 70/100
# 721/721 [==============================] - 23s 31ms/step - loss: 0.2371 - accuracy: 0.9009 - val_loss: 0.3130 - val_accuracy: 0.8858
# Epoch 71/100
# 721/721 [==============================] - 20s 28ms/step - loss: 0.2370 - accuracy: 0.8997 - val_loss: 0.3082 - val_accuracy: 0.8831
# Epoch 72/100
# 721/721 [==============================] - 22s 30ms/step - loss: 0.2355 - accuracy: 0.9007 - val_loss: 0.2962 - val_accuracy: 0.8849
# Epoch 73/100
# 721/721 [==============================] - 20s 28ms/step - loss: 0.2356 - accuracy: 0.8988 - val_loss: 0.3119 - val_accuracy: 0.8850
# Epoch 74/100
# 721/721 [==============================] - 20s 28ms/step - loss: 0.2347 - accuracy: 0.9003 - val_loss: 0.3082 - val_accuracy: 0.8824
# Epoch 75/100
# 721/721 [==============================] - 22s 31ms/step - loss: 0.2339 - accuracy: 0.9025 - val_loss: 0.3021 - val_accuracy: 0.8838
# Epoch 76/100
# 721/721 [==============================] - 20s 28ms/step - loss: 0.2342 - accuracy: 0.8994 - val_loss: 0.3180 - val_accuracy: 0.8844
# Epoch 77/100
# 721/721 [==============================] - 22s 31ms/step - loss: 0.2329 - accuracy: 0.8999 - val_loss: 0.3110 - val_accuracy: 0.8864
# Epoch 78/100
# 721/721 [==============================] - 20s 28ms/step - loss: 0.2346 - accuracy: 0.8997 - val_loss: 0.3055 - val_accuracy: 0.8842
# Epoch 79/100
# 721/721 [==============================] - 22s 30ms/step - loss: 0.2297 - accuracy: 0.9028 - val_loss: 0.3149 - val_accuracy: 0.8831
# Epoch 80/100
# 721/721 [==============================] - 20s 28ms/step - loss: 0.2301 - accuracy: 0.9027 - val_loss: 0.3192 - val_accuracy: 0.8833
# Epoch 81/100
# 721/721 [==============================] - 21s 30ms/step - loss: 0.2305 - accuracy: 0.9014 - val_loss: 0.3215 - val_accuracy: 0.8836
# Epoch 82/100
# 721/721 [==============================] - 21s 29ms/step - loss: 0.2340 - accuracy: 0.9009 - val_loss: 0.3201 - val_accuracy: 0.8820
# Epoch 83/100
# 721/721 [==============================] - 20s 28ms/step - loss: 0.2275 - accuracy: 0.9029 - val_loss: 0.3245 - val_accuracy: 0.8831
# Epoch 84/100
# 721/721 [==============================] - 22s 31ms/step - loss: 0.2343 - accuracy: 0.9017 - val_loss: 0.3211 - val_accuracy: 0.8817
# Epoch 85/100
# 721/721 [==============================] - 20s 28ms/step - loss: 0.2319 - accuracy: 0.9002 - val_loss: 0.3106 - val_accuracy: 0.8825
# Epoch 86/100
# 721/721 [==============================] - 23s 32ms/step - loss: 0.2290 - accuracy: 0.9030 - val_loss: 0.3459 - val_accuracy: 0.8833
# Epoch 87/100
# 721/721 [==============================] - 20s 28ms/step - loss: 0.2313 - accuracy: 0.9004 - val_loss: 0.3292 - val_accuracy: 0.8833
# Epoch 88/100
# 721/721 [==============================] - 22s 31ms/step - loss: 0.2277 - accuracy: 0.9036 - val_loss: 0.3171 - val_accuracy: 0.8838
# Epoch 89/100
# 721/721 [==============================] - 20s 28ms/step - loss: 0.2284 - accuracy: 0.9022 - val_loss: 0.3350 - val_accuracy: 0.8840
# Epoch 90/100
# 721/721 [==============================] - 22s 30ms/step - loss: 0.2276 - accuracy: 0.9020 - val_loss: 0.3220 - val_accuracy: 0.8812
# Epoch 91/100
# 721/721 [==============================] - 20s 28ms/step - loss: 0.2291 - accuracy: 0.9024 - val_loss: 0.3364 - val_accuracy: 0.8852
# Epoch 92/100
# 721/721 [==============================] - 22s 30ms/step - loss: 0.2274 - accuracy: 0.9026 - val_loss: 0.3219 - val_accuracy: 0.8835
# Epoch 93/100
# 721/721 [==============================] - 21s 29ms/step - loss: 0.2269 - accuracy: 0.9018 - val_loss: 0.3130 - val_accuracy: 0.8867
# Epoch 94/100
# 721/721 [==============================] - 20s 28ms/step - loss: 0.2286 - accuracy: 0.9019 - val_loss: 0.3361 - val_accuracy: 0.8835
# Epoch 95/100
# 721/721 [==============================] - 22s 31ms/step - loss: 0.2261 - accuracy: 0.9026 - val_loss: 0.3318 - val_accuracy: 0.8850
# Epoch 96/100
# 721/721 [==============================] - 20s 28ms/step - loss: 0.2285 - accuracy: 0.9034 - val_loss: 0.3313 - val_accuracy: 0.8856
# Epoch 97/100
# 721/721 [==============================] - 23s 32ms/step - loss: 0.2254 - accuracy: 0.9049 - val_loss: 0.3167 - val_accuracy: 0.8833
# Epoch 98/100
# 721/721 [==============================] - 20s 28ms/step - loss: 0.2238 - accuracy: 0.9033 - val_loss: 0.3279 - val_accuracy: 0.8835
# Epoch 99/100
# 721/721 [==============================] - 22s 31ms/step - loss: 0.2276 - accuracy: 0.9027 - val_loss: 0.3255 - val_accuracy: 0.8844
# Epoch 100/100
# 721/721 [==============================] - 20s 28ms/step - loss: 0.2237 - accuracy: 0.9032 - val_loss: 0.3433 - val_accuracy: 0.8835

# %%
# Evaluate the model
score = model.evaluate(X_test_scaled, y_test)
print("Test loss:", score[0])
print("Test accuracy:", score[1])
# Out:
# 772/772 [==============================] - 10s 13ms/step - loss: 0.3196 - accuracy: 0.8799
# Test loss: 0.3195796310901642
# Test accuracy: 0.8798785209655762

# %%
# Make predictions
y_pred = np.argmax(model.predict(X_test_scaled), axis=-1)

# Calculate prediction probabilities
y_score = model.predict(X_test_scaled)

# Convert one-hot encoded y_test to class labels
y_test_labels = np.argmax(y_test, axis=-1)

# Print scores
print_score(y_pred, y_test_labels, y_score, label_encoder, model_name)
# Out:
# 772/772 [==============================] - 8s 10ms/step
# 772/772 [==============================] - 5s 6ms/step
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#                         Metric     Value
# 0                     Accuracy  0.879879
# 1            Precision (macro)  0.476046
# 2               Recall (macro)  0.473199
# 3             F1-score (macro)  0.464940
# 4              AUC-ROC (macro)  0.975833
# 5         Precision (Analysis)  0.000000
# 6            Recall (Analysis)  0.000000
# 7          F1-score (Analysis)  0.000000
# 8         Precision (Backdoor)  0.000000
# 9            Recall (Backdoor)  0.000000
# 10         F1-score (Backdoor)  0.000000
# 11             Precision (DoS)  0.432320
# 12                Recall (DoS)  0.528270
# 13              F1-score (DoS)  0.475503
# 14        Precision (Exploits)  0.674508
# 15           Recall (Exploits)  0.735680
# 16         F1-score (Exploits)  0.703767
# 17         Precision (Fuzzers)  0.709355
# 18            Recall (Fuzzers)  0.787340
# 19          F1-score (Fuzzers)  0.746316
# 20         Precision (Generic)  0.995431
# 21            Recall (Generic)  0.966637
# 22          F1-score (Generic)  0.980823
# 23          Precision (Normal)  0.994585
# 24             Recall (Normal)  0.988607
# 25           F1-score (Normal)  0.991587
# 26  Precision (Reconnaissance)  0.732039
# 27     Recall (Reconnaissance)  0.708647
# 28   F1-score (Reconnaissance)  0.720153
# 29       Precision (Shellcode)  0.222222
# 30          Recall (Shellcode)  0.016807
# 31        F1-score (Shellcode)  0.031250
# 32           Precision (Worms)  0.000000
# 33              Recall (Worms)  0.000000
# 34            F1-score (Worms)  0.000000

# %%
# Plot ROC curve
plot_roc_curve(y_test_labels, y_score, label_encoder, model_name)

# %%
# Plot Precision-Recall curve
plot_precision_recall_curve(y_test, y_score, label_encoder, model_name)

# %%
plot_class_accuracy(y_test_labels, y_pred, label_encoder)

# %%
from sklearn.metrics import f1_score

def plot_class_f1_score(y_true, y_pred, label_encoder):
    n_classes = len(label_encoder.classes_)
    f1_scores = []

    for i in range(n_classes):
        class_f1_score = f1_score(y_true, y_pred, labels=[i], average='weighted')
        f1_scores.append(class_f1_score)

    class_names = label_encoder.inverse_transform(range(n_classes))

    plt.figure(figsize=(10, 6))
    plt.bar(class_names, f1_scores)
    plt.xlabel('Class')
    plt.ylabel('F1-score')
    plt.title('F1-score per Class')
    plt.xticks(rotation=45)
    plt.ylim([0.0, 1.05])
    fig = plt.gcf()  # Get the current figure
    plt.show()
    
    # Save the figure to an image file
    fig.savefig(f"{model_name}_class_f1_score.png", bbox_inches='tight')

plot_class_f1_score(y_test_labels, y_pred, label_encoder)

# %%
import pandas as pd

# Load the CSV file
metrics_file = "CNN_metrics.csv"
metrics_df = pd.read_csv(metrics_file)

# Print the contents of the file
print(metrics_df)
# Out:
#                         Metric     Value
# 0                     Accuracy  0.879879
# 1            Precision (macro)  0.476046
# 2               Recall (macro)  0.473199
# 3             F1-score (macro)  0.464940
# 4              AUC-ROC (macro)  0.975833
# 5         Precision (Analysis)  0.000000
# 6            Recall (Analysis)  0.000000
# 7          F1-score (Analysis)  0.000000
# 8         Precision (Backdoor)  0.000000
# 9            Recall (Backdoor)  0.000000
# 10         F1-score (Backdoor)  0.000000
# 11             Precision (DoS)  0.432320
# 12                Recall (DoS)  0.528270
# 13              F1-score (DoS)  0.475503
# 14        Precision (Exploits)  0.674508
# 15           Recall (Exploits)  0.735680
# 16         F1-score (Exploits)  0.703767
# 17         Precision (Fuzzers)  0.709355
# 18            Recall (Fuzzers)  0.787340
# 19          F1-score (Fuzzers)  0.746316
# 20         Precision (Generic)  0.995431
# 21            Recall (Generic)  0.966637
# 22          F1-score (Generic)  0.980823
# 23          Precision (Normal)  0.994585
# 24             Recall (Normal)  0.988607
# 25           F1-score (Normal)  0.991587
# 26  Precision (Reconnaissance)  0.732039
# 27     Recall (Reconnaissance)  0.708647
# 28   F1-score (Reconnaissance)  0.720153
# 29       Precision (Shellcode)  0.222222
# 30          Recall (Shellcode)  0.016807
# 31        F1-score (Shellcode)  0.031250
# 32           Precision (Worms)  0.000000
# 33              Recall (Worms)  0.000000
# 34            F1-score (Worms)  0.000000
